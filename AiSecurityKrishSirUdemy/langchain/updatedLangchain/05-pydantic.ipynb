# %% [markdown]
# ### Structured Output

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model  = init_chat_model("groq:qwen/qwen3.6-27b", temperature=0.7)

# %%
from pydantic import BaseModel, Field

class Movie(BaseModel):
    title: str = Field(description="Title of the movie")
    year: int = Field(description="This year the movie was released")
    director: str = Field(description="the director of the movie")
    rating: float = Field(description="The movies ratings out of 10")

# %%
model_with_structure = model.with_structured_output(Movie)

# %%
model_with_structure.invoke("Provide deatils about the movie intrtstailer")
# Out:
# Movie(title='Interstellar', year=2014, director='Christopher Nolan', rating=8.7)

# %%
### messgae output
model_with_structure = model.with_structured_output(Movie,include_raw=True)

# %%
res=model_with_structure.invoke("Provide deatils about the movie intrtstailer")
res['raw']
# Out:
# AIMessage(content='', additional_kwargs={'reasoning_content': 'Here\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - User asks: "Provide deatils about the movie intrtstailer"\n   - There\'s a typo: "intrtstailer" likely means "Intrastailer" or something similar. Let me think about movie titles that match this.\n   - Could it be "Intrastellar"? Probably "Interstellar" by Christopher Nolan.\n   - Let\'s verify: "Interstellar" is a famous 2014 movie directed by Christopher Nolan, rated around 8.6/10.\n   - The typo "intrtstailer" is very close to "Interstellar" if we consider keyboard slips or autocorrect issues. I\'ll assume they mean "Interstellar".\n\n2.  **Identify Required Parameters for Tool:**\n   - The `Movie` tool requires: `title`, `year`, `director`, `rating`\n   - For "Interstellar":\n     - title: "Interstellar"\n     - year: 2014\n     - director: "Christopher Nolan"\n     - rating: 8.6 (out of 10, commonly cited from IMDb)\n\n3.  **Construct Tool Call:**\n   - 
# ...

# %% [markdown]
# ### TypeDict

# %%
from typing_extensions import TypedDict, Annotated

class MovieDict(BaseModel):
    title: str = Field(description="Title of the movie")
    year: int = Field(description="This year the movie was released")
    director: str = Field(description="the director of the movie")
    rating: float = Field(description="The movies ratings out of 10")

model_with_typedict = model.with_structured_output(MovieDict)
model_with_typedict.invoke("avengers")
# Out:
# MovieDict(title='The Avengers', year=2012, director='Joss Whedon', rating=8.0)

# %%
print(model.profile)
# Out:
# None

# %% [markdown]
# ### Data classes

# %%
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
## data classs

from dataclasses import dataclass
from langchain.agents import create_agent

@dataclass
class ContactInfo:
    """Contact info for a person"""
    name: str
    email: str
    phone: str


agent = create_agent(
    model="google_genai:gemini-2.5-flash",
    response_format=ContactInfo
)
result=agent.invoke({"messages": [{"role": "user", "content": "Extract content info kishan kishanghosh090@gmail.com 9635859574"}]})
result['structured_response']
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/Desktop/RAG/AiSecurityKrishSirUdemy/langchain/.venv/lib/python3.14/site-packages/langchain_google_genai/chat_models.py:3379, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3378 try:
# -> 3379     response: GenerateContentResponse = self.client.models.generate_content(
#    3380         **request,
#    3381     )
#    3382 except ClientError as e:
#
# File ~/Desktop/RAG/AiSecurityKrishSirUdemy/langchain/.venv/lib/python3.14/site-packages/google/genai/models.py:6641, in Models.generate_content(self, model, contents, config)
#    6640 i += 1
# -> 6641 response = self._generate_content(
#    6642     model=model, contents=contents, config=parsed_config_to_call
#    6643 )
# ...
