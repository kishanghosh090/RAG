# %% [markdown]
# ### Tools

# %%
import os 
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

## qwen using groq model 
model_groq = init_chat_model("groq:qwen/qwen3.6-27b", temperature=0.7)

# %%
from langchain.tools import tool

@tool
def get_current_weather(location: str) -> str:
    """Get the current weather in a given location"""
    return f"The current weather in {location} is sunny with a temperature of 25 degrees Celsius."

model_with_tools = model_groq.bind_tools([get_current_weather])

res = model_with_tools.invoke("What is the current weather in New York?")
print(res)

for tool_call in res.tool_calls:
    print(f"Tool called: {tool_call['name']}")
    print(f"Tool output: {tool_call['args']}")
# Out:
# content='' additional_kwargs={'reasoning_content': 'Thinking Process:\n1.  Identify user intent: Get current weather in New York.\n2.  Identify available tools: `get_current_weather(location: string)`.\n3.  Extract parameters: location = "New York".\n4.  Call the tool.\n5.  Formulate response based on tool output. (Self-correction/Refinement: I will just call the tool first.)\nWait, I need to generate the tool call. I will output the tool call format.\nParameters: `{"location": "New York"}`.\nFormat:\n<tool_call>\n<function=get_current_weather>\n<parameter=location>\nNew York\n</parameter>\n</function>\n</tool_call>\nDone. \nProceed. \nNo extra fluff. Output matches exactly.✅\nCheck tool definition: `get_current_weather` takes `location` (string). Required.\nMatches. Output generation. \n(Self-Correction/Verification during thought: The prompt says "What is the current weather in New York?". I will just call the function.)\nReady. \nOutput matches response. \nProceeds. \n[Output Gene
# ...
